# %%
import pandas as pd 
import matplotlib.pyplot as plt


dashboard = pd.read_excel('C:\\Users\\Ben\\Documents\\git\\Finance-KPIs\\MRR data.xlsx', index_col=0)

fig, [[ax1, ax2, ax3], [ax4, ax5, ax6]] = plt.subplots(2,3)


month_labels = ['Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec', 'Jan', 'Feb', 'Mar']

MRR_data = dashboard.iloc[[4,5,6,7],:].set_axis(month_labels, axis='columns')
MRR_data_plot = MRR_data.swapaxes('index','columns')
ax1.set_xticks([50000, 100000, 150000, 200000, 250000])
ax1.set_xticklabels(['50k', '100k', '150k', '200k', '250k'])
MRR_data_plot.plot.bar(ax=ax1)


print(MRR_data_plot)

MRR_data_plot.plot.bar(ax=ax1)

plt.show()
# Out:
#        2018-19    2019-20    2020-21    2021-22
# Apr   10151.66   48213.05    90888.5  191622.18
# May       8870   52230.16     108920  198979.17
# Jun      34865   62788.78  119976.45        NaN
# Jul      30865   65751.64  112915.81        NaN
# Aug      46860   96065.66   97012.68        NaN
# Sep      50500   78242.76  132769.87        NaN
# Oct      58005   86326.28  104536.77        NaN
# Nov      58845     155350  114713.58        NaN
# Dec   97783.75  119999.11  109385.86        NaN
# Jan   72988.75  162294.93  163900.24        NaN
# Feb    91079.5  114902.32  194880.83        NaN
# Mar  142295.09  159277.87   170969.9        NaN
